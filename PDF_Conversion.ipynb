# %%
import tabula

# %%
PDF = r"D:\2020\VIC\PDF\01_AGS_DV2020.pdf"

# %%
tables = tabula.read_pdf(PDF, pages = "all", multiple_tables = True)
tables
# Out:
# Got stderr: jun 25, 2020 5:30:20 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# ADVERTENCIA: New fonts found, font cache will be re-built
# jun 25, 2020 5:30:20 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Building on-disk font cache, this may take a while
# jun 25, 2020 5:30:21 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# ADVERTENCIA: Finished building on-disk font cache, found 450 fonts
# [                                        L U    G    A    R  Unnamed: 0    E S  \
#  0                                       NaN  NaN  NaN  NaN         NaN     KM
#  1   T. C. Aguascalientes - Zacatecas (Alta)  NaN  NaN  NaN         NaN   0.00
#  2   T. C. Aguascalientes - Zacatecas (Baja)  NaN  NaN  NaN         NaN   0.00
#  3   T. C. Aguascalientes - Zacatecas (Alta)  NaN  NaN  NaN         NaN   0.00
#  4   T. C. Aguascalientes - Zacatecas (Baja)  NaN  NaN  NaN         NaN   0.00
# ...

# %%
tabula.convert_into(PDF, r"D:/AGS_all.xls", pages = "all")
