# %%
import pandas as pd
from pandas import read_csv
import json

# %%
csv = pd.read_csv(r'/Volumes/Toshiba/ZAnalytics/BD/Maps/Migration_map/2021_Enero_Junio.csv', encoding= 'utf_8_sig')
csv
# Out:
#                  from               to                  labels    color  \
# 0      -97.362,40.448  -101.295,22.837  Estados Unidos, Mexico  #081666
# 1       -74.014,4.683  -101.295,22.838        Colombia, Mexico  #e3d10e
# 2      -51.675,-7.934  -101.295,22.839          Brasil, Mexico  #078c2b
# 3       -65.309,7.518  -101.295,22.840       Venezuela, Mexico  #d93407
# 4      -78.287,-1.125  -101.295,22.841         Ecuador, Mexico  #dbcb18
# 5       -3.443,40.641  -101.295,22.842          Espana, Mexico  #f7362f
# 6       -103.71,59.35  -101.295,22.843          Canada, Mexico  #ff0000
# 7     -64.334,-32.783  -101.295,22.844       Argentina, Mexico  #00baed
# 8        2.770,46.861  -101.295,22.845         Francia, Mexico  #141b82
# 9      -75.082,-9.385  -101.295,22.846            Peru, Mexico  #b81004
# 10      10.402,51.190  -101.295,22.847        Alemania, Mexico  #edda02
# 11    -83.8576,9.9657  -101.295,22.848      Costa Rica, Mexico  #0042ad
# ...

# %%
del csv['labels']

# %%
json = csv.to_json(orient='records')
json
# Out:
# '[{"from":"-97.362,40.448","to":"-101.295,22.837","color":"#081666","value":4424529},{"from":"-74.014,4.683","to":"-101.295,22.838","color":"#e3d10e","value":141307},{"from":"-51.675,-7.934","to":"-101.295,22.839","color":"#078c2b","value":124620},{"from":"-65.309,7.518","to":"-101.295,22.840","color":"#d93407","value":71743},{"from":"-78.287,-1.125","to":"-101.295,22.841","color":"#dbcb18","value":63744},{"from":"-3.443,40.641","to":"-101.295,22.842","color":"#f7362f","value":63619},{"from":"-103.71,59.35","to":"-101.295,22.843","color":"#ff0000","value":55694},{"from":"-64.334,-32.783","to":"-101.295,22.844","color":"#00baed","value":50251},{"from":"2.770,46.861","to":"-101.295,22.845","color":"#141b82","value":45286},{"from":"-75.082,-9.385","to":"-101.295,22.846","color":"#b81004","value":43733},{"from":"10.402,51.190","to":"-101.295,22.847","color":"#edda02","value":39792},{"from":"-83.8576,9.9657","to":"-101.295,22.848","color":"#0042ad","value":37731},{"from":"-70.8482,-32.079
# ...
