# %%
import geopandas as gdp

# %%
gdf = gdp.read_file(r'D:\2021\CARTO_MIGRATION\JSON\agebs_puntos_wgs_date.geojson')
gdf

# %%
gdf
# Out:
#         cartodb_id  objectid         cvegeo cve_ent cve_mun cve_ageb cve_loc  \
# 0                1         2      150030136      15     003     0136    None
# 1                2         3      150030174      15     003     0174    None
# 2                3         5      150030140      15     003     0140    None
# 3                4        10      150050249      15     005     0249    None
# 4                5        11      15005022A      15     005     022A    None
# ...            ...       ...            ...     ...     ...      ...     ...
# 864558      864880   1141433  0901700010437      09     017     0437    0001
# 864559      864881   1141434  0901700010441      09     017     0441    0001
# 864560      864882   1141435  0901700010545      09     017     0545    0001
# 864561      864883   1141436  090170001055A      09     017     055A    0001
# 864562      864884   1141437  0901700010564      09     017     0564    0001
#
# ...
