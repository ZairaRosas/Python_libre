# %%
import pandas as pd
from pandas import read_csv
import json

# %%
csv = pd.read_csv(r'/Volumes/Toshiba/ZAnalytics/BD/Maps/Migration_map/2020_Enero_Junio.csv', encoding= 'utf_8_sig')
csv
# Out:
#                  from               to                  labels    color  \
# 0      -97.362,40.448  -101.295,22.837  Estados Unidos, Mexico  #081666
# 1       -74.014,4.683  -101.295,22.838        Colombia, Mexico  #e3d10e
# 2      -51.675,-7.934  -101.295,22.839          Brasil, Mexico  #078c2b
# 3       -65.309,7.518  -101.295,22.840       Venezuela, Mexico  #d93407
# 4      -78.287,-1.125  -101.295,22.841         Ecuador, Mexico  #dbcb18
# 5       -3.443,40.641  -101.295,22.842          Espana, Mexico  #f7362f
# 6       -103.71,59.35  -101.295,22.843          Canada, Mexico  #ff0000
# 7     -64.334,-32.783  -101.295,22.844       Argentina, Mexico  #00baed
# 8        2.770,46.861  -101.295,22.845         Francia, Mexico  #141b82
# 9      -75.082,-9.385  -101.295,22.846            Peru, Mexico  #b81004
# 10      10.402,51.190  -101.295,22.847        Alemania, Mexico  #edda02
# 11    -83.8576,9.9657  -101.295,22.848      Costa Rica, Mexico  #0042ad
# ...

# %%
json = csv.to_json(orient='records')
json
# Out:
# '[{"from":"-97.362,40.448","to":"-101.295,22.837","labels":"Estados Unidos, Mexico","color":"#081666","value":2505825},{"from":"-74.014,4.683","to":"-101.295,22.838","labels":"Colombia, Mexico","color":"#e3d10e","value":118072},{"from":"-51.675,-7.934","to":"-101.295,22.839","labels":"Brasil, Mexico","color":"#078c2b","value":87837},{"from":"-65.309,7.518","to":"-101.295,22.840","labels":"Venezuela, Mexico","color":"#d93407","value":20059},{"from":"-78.287,-1.125","to":"-101.295,22.841","labels":"Ecuador, Mexico","color":"#dbcb18","value":37037},{"from":"-3.443,40.641","to":"-101.295,22.842","labels":"Espana, Mexico","color":"#f7362f","value":67038},{"from":"-103.71,59.35","to":"-101.295,22.843","labels":"Canada, Mexico","color":"#ff0000","value":886099},{"from":"-64.334,-32.783","to":"-101.295,22.844","labels":"Argentina, Mexico","color":"#00baed","value":86180},{"from":"2.770,46.861","to":"-101.295,22.845","labels":"Francia, Mexico","color":"#141b82","value":89013},{"from":"-75.082
# ...
