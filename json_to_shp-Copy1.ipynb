# %%
from pandas.io.json import json_normalize
import pandas as pd
from geopandas import GeoDataFrame
from shapely import wkt
import matplotlib.pyplot as plt

# %%
geojson = pd.read_json(r'D:\2021\OD_MATRIX_AUTO\OUTPUTS\TomTom_20210204\TJ.json')

# %%
df = pd.json_normalize(geojson["features"])
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates
# 0    [[[-116.7847436043507, 32.509152144038524], [-...
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...
# 3    [[[-116.806084931249, 32.509152144038524], [-1...
# 4    [[[-116.806084931249, 32.49116573676403], [-11...
# ..                                                 ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...
# 117  [[[-117.08349199041547, 32.52714129741736], [-...
# 118  [[[-117.06088910191033, 32.53983054745626], [-...
# 119  [[[-117.03702758388104, 32.54173156986951], [-...
# 120  [[[-117.01962269668269, 32.54341521947734], [-...
#
# [121 rows x 5 columns]

# %%
df.dtypes
# Out:
# type                    object
# properties.name         object
# properties.i             int64
# geometry.type           object
# geometry.coordinates    object
# dtype: object

# %%
df['region'] = df['properties.name'].astype(str)
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
# [121 rows x 6 columns]

# %%
df['geom'] = df['geometry.coordinates'].astype(str)
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region  \
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
#                                                   geom
# 0    [[[-116.7847436043507, 32.509152144038524], [-...
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...
# 3    [[[-116.806084931249, 32.509152144038524], [-1...
# 4    [[[-116.806084931249, 32.49116573676403], [-11...
# ..                                                 ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...
# 117  [[[-117.08349199041547, 32.52714129741736], [-...
# 118  [[[-117.06088910191033, 32.53983054745626], [-...
# 119  [[[-117.03702758388104, 32.54173156986951], [-...
# 120  [[[-117.01962269668269, 32.54341521947734], [-...
#
# [121 rows x 7 columns]

# %%
df['geom'] = df['geom'].str.replace(", ", " ")
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region  \
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
#                                                   geom
# 0    [[[-116.7847436043507 32.509152144038524] [-11...
# 1    [[[-116.7847436043507 32.49116573676403] [-116...
# 2    [[[-116.7847436043507 32.47317932948954] [-116...
# 3    [[[-116.806084931249 32.509152144038524] [-116...
# 4    [[[-116.806084931249 32.49116573676403] [-116....
# ..                                                 ...
# 116  [[[-117.10488869229665 32.527185513944204] [-1...
# 117  [[[-117.08349199041547 32.52714129741736] [-11...
# 118  [[[-117.06088910191033 32.53983054745626] [-11...
# 119  [[[-117.03702758388104 32.54173156986951] [-11...
# 120  [[[-117.01962269668269 32.54341521947734] [-11...
#
# [121 rows x 7 columns]

# %%
df['geom'] = df['geom'].str.replace('] [' , ', ', regex=False)
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region  \
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
#                                                   geom
# 0    [[[-116.7847436043507 32.509152144038524, -116...
# 1    [[[-116.7847436043507 32.49116573676403, -116....
# 2    [[[-116.7847436043507 32.47317932948954, -116....
# 3    [[[-116.806084931249 32.509152144038524, -116....
# 4    [[[-116.806084931249 32.49116573676403, -116.8...
# ..                                                 ...
# 116  [[[-117.10488869229665 32.527185513944204, -11...
# 117  [[[-117.08349199041547 32.52714129741736, -117...
# 118  [[[-117.06088910191033 32.53983054745626, -117...
# 119  [[[-117.03702758388104 32.54173156986951, -117...
# 120  [[[-117.01962269668269 32.54341521947734, -117...
#
# [121 rows x 7 columns]

# %%
df['geom'] = df['geom'].str.replace('[[[' , 'POLYGON((', regex=False)
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region  \
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
#                                                   geom
# 0    POLYGON((-116.7847436043507 32.509152144038524...
# 1    POLYGON((-116.7847436043507 32.49116573676403,...
# 2    POLYGON((-116.7847436043507 32.47317932948954,...
# 3    POLYGON((-116.806084931249 32.509152144038524,...
# 4    POLYGON((-116.806084931249 32.49116573676403, ...
# ..                                                 ...
# 116  POLYGON((-117.10488869229665 32.52718551394420...
# 117  POLYGON((-117.08349199041547 32.52714129741736...
# 118  POLYGON((-117.06088910191033 32.53983054745626...
# 119  POLYGON((-117.03702758388104 32.54173156986951...
# 120  POLYGON((-117.01962269668269 32.54341521947734...
#
# [121 rows x 7 columns]

# %%
df['geom'] = df['geom'].str.replace(']]]' , '))', regex=False)
df
# Out:
#         type properties.name  properties.i geometry.type  \
# 0    Feature        Region 4             0       Polygon
# 1    Feature        Region 5             1       Polygon
# 2    Feature        Region 6             2       Polygon
# 3    Feature       Region 13             3       Polygon
# 4    Feature       Region 14             4       Polygon
# ..       ...             ...           ...           ...
# 116  Feature      Region 158           116       Polygon
# 117  Feature      Region 159           117       Polygon
# 118  Feature      Region 160           118       Polygon
# 119  Feature      Region 161           119       Polygon
# 120  Feature      Region 162           120       Polygon
#
#                                   geometry.coordinates      region  \
# 0    [[[-116.7847436043507, 32.509152144038524], [-...    Region 4
# 1    [[[-116.7847436043507, 32.49116573676403], [-1...    Region 5
# 2    [[[-116.7847436043507, 32.47317932948954], [-1...    Region 6
# 3    [[[-116.806084931249, 32.509152144038524], [-1...   Region 13
# 4    [[[-116.806084931249, 32.49116573676403], [-11...   Region 14
# ..                                                 ...         ...
# 116  [[[-117.10488869229665, 32.527185513944204], [...  Region 158
# 117  [[[-117.08349199041547, 32.52714129741736], [-...  Region 159
# 118  [[[-117.06088910191033, 32.53983054745626], [-...  Region 160
# 119  [[[-117.03702758388104, 32.54173156986951], [-...  Region 161
# 120  [[[-117.01962269668269, 32.54341521947734], [-...  Region 162
#
#                                                   geom
# 0    POLYGON((-116.7847436043507 32.509152144038524...
# 1    POLYGON((-116.7847436043507 32.49116573676403,...
# 2    POLYGON((-116.7847436043507 32.47317932948954,...
# 3    POLYGON((-116.806084931249 32.509152144038524,...
# 4    POLYGON((-116.806084931249 32.49116573676403, ...
# ..                                                 ...
# 116  POLYGON((-117.10488869229665 32.52718551394420...
# 117  POLYGON((-117.08349199041547 32.52714129741736...
# 118  POLYGON((-117.06088910191033 32.53983054745626...
# 119  POLYGON((-117.03702758388104 32.54173156986951...
# 120  POLYGON((-117.01962269668269 32.54341521947734...
#
# [121 rows x 7 columns]

# %%
data = df[['region','geom']]
data
# Out:
#          region                                               geom
# 0      Region 4  POLYGON((-116.7847436043507 32.509152144038524...
# 1      Region 5  POLYGON((-116.7847436043507 32.49116573676403,...
# 2      Region 6  POLYGON((-116.7847436043507 32.47317932948954,...
# 3     Region 13  POLYGON((-116.806084931249 32.509152144038524,...
# 4     Region 14  POLYGON((-116.806084931249 32.49116573676403, ...
# ..          ...                                                ...
# 116  Region 158  POLYGON((-117.10488869229665 32.52718551394420...
# 117  Region 159  POLYGON((-117.08349199041547 32.52714129741736...
# 118  Region 160  POLYGON((-117.06088910191033 32.53983054745626...
# 119  Region 161  POLYGON((-117.03702758388104 32.54173156986951...
# 120  Region 162  POLYGON((-117.01962269668269 32.54341521947734...
#
# [121 rows x 2 columns]

# %%
data['geom'] = data['geom'].apply(wkt.loads)

gdf = GeoDataFrame(data, geometry = 'geom')
gdf
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          region                                               geom
# 0      Region 4  POLYGON ((-116.78474 32.50915, -116.78474 32.4...
# 1      Region 5  POLYGON ((-116.78474 32.49117, -116.78474 32.4...
# 2      Region 6  POLYGON ((-116.78474 32.47318, -116.78474 32.4...
# 3     Region 13  POLYGON ((-116.80608 32.50915, -116.80608 32.4...
# 4     Region 14  POLYGON ((-116.80608 32.49117, -116.80608 32.4...
# ..          ...                                                ...
# 116  Region 158  POLYGON ((-117.10489 32.52719, -117.10447 32.5...
# 117  Region 159  POLYGON ((-117.08349 32.52714, -117.08265 32.5...
# 118  Region 160  POLYGON ((-117.06089 32.53983, -117.06225 32.5...
# 119  Region 161  POLYGON ((-117.03703 32.54173, -117.03551 32.5...
# 120  Region 162  POLYGON ((-117.01962 32.54342, -117.05227 32.5...
#
# [121 rows x 2 columns]

# %%
#Shapefile 1
gdf.to_file(r'D:\2021\OD_MATRIX_AUTO\SHP\TomTom_20210204\TJ.shp', encoding='latin1')
