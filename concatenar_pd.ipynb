# %%
import pandas as pd
import geopandas
from pandas import read_csv
from shapely import wkt
from geopandas import GeoDataFrame, points_from_xy

# %%
#seleccionar tablas
table_1 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p1.csv', encoding="latin-1")
table_2 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p2.csv', encoding="latin-1")
table_3 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p3.csv', encoding="latin-1")
table_4 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p4.csv', encoding="latin-1")
table_5 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p5.csv', encoding="latin-1")
table_6 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p6.csv', encoding="latin-1")
table_7 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p7.csv', encoding="latin-1")
table_8 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p8.csv', encoding="latin-1")
table_9 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p9.csv', encoding="latin-1")
table_10 = read_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_p10.csv', encoding="latin-1")

# %%
concatenar_tablas = pd.concat([table_1, table_2, table_3, table_4, table_5, table_6, table_7, table_8, table_9, table_10])
concatenar_tablas.sort_values(by='ts', ascending=True)
# Out:
#        Unnamed: 0            city turntype  level country  speedKMH  delay  \
# 12754      105139      Iztapalapa     NONE      4      MX      7.31    252
# 2740       132841      Iztapalapa     NONE      3      MX      9.81    225
# 42735      243774  Benito JuÃ¡rez     NONE      3      MX     10.15    218
# 24370      139487      Iztapalapa     NONE      3      MX      8.32    363
# 8677       173413      Iztapalapa     NONE      3      MX     11.40    131
# ...           ...             ...      ...    ...     ...       ...    ...
# 14651      199925      Iztapalapa     NONE      3      MX     17.02     87
# 24217       54561  Benito JuÃ¡rez     NONE      3      MX      9.09     69
# 24378       66527  Benito JuÃ¡rez     NONE      3      MX      7.54    108
# 4976       276236      Iztapalapa     NONE      3      MX     16.51     94
# 48012      212647       Iztacalco     NONE      3      MX      3.70    125
#
# ...

# %%
concatenar_tablas.to_csv(r'F:\Waze\JAMS\Descargas_BigQuery\2021_05_12_mb_eje5_eje6\Separados\2021\jams_202105_mb_eje5_eje6_completo.csv')

# %%
concatenar_tablas['geoWKT'] = concatenar_tablas['geoWKT'].apply(wkt.loads)

gdf = GeoDataFrame(concatenar_tablas, geometry = 'geoWKT')
gdf
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-728fc3f678ca> in <module>
# ----> 1 concatenar_tablas['geoWKT'] = concatenar_tablas['geoWKT'].apply(wkt.loads)
#       2
#       3 gdf = GeoDataFrame(concatenar_tablas, geometry = 'geoWKT')
#       4 gdf
#
# d:\programs\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# d:\programs\python39\lib\site-packages\shapely\wkt.py in loads(data)
#      20     Shapely geometry object
#      21     """
# ---> 22     return geos.WKTReader(geos.lgeos).read(data)
# ...

# %%
#Shapefile 1
gdf.to_file(r'D:\2020\HUIXQUILUCAN\Alertas\shp_limpios\alerts_huixquilucan_20191201_20201210.shp')
